# %% [markdown]
# # **A map of Paris cultural life**
#
# This notebook will provide the main results we obtained through our work. It allows anyone to use the functions without having to use the Interface.
# It is divided in 3 subsequence:
#
# I- Maps
#
# II-Statistics
#
# III. Scrapping (Optional)

# %% [markdown]
# ## **I. Maps**
#
# This section will allow you to create the Maps we create through the interface. Each cell is dedicated to a function and an example is always provided. We use the databases create by webscrapping, if you want to learn more on how we did it, go to the final section named Scrapping.
#
#
#  The functions defined below are very similar to those defined in the mapping files of each folder. The mapping.py files are the functions we use in the interface and are programmed to open directly a window in your webbrowser with the map. The only thing we change in the following functions is that we deleted the order to open a new window with the map created. If you want to open the map, you need to go to Output/Maps and to open them in a webbrowser. JupyterLab does it by itself but some code editor as VSCODE may require an additionnal extension.
#
#  We first import the main modules we are going to use:

# %%
import folium
import pandas as pd 
from folium.plugins import MarkerCluster
from datetime import datetime

# %% [markdown]
# ### Cinema
#
# The following sub-section gives you the code to plot the maps of all the movie displayed on a day. This uses the database DataCinema.csv created in the scrapping section. Pay attention that not all the cinemas of Paris are represented on the maps but lots of them are (additional details are provided in the code of the scrapping section).
#
# All the more, the database hasn't been uptated since 28 th december 2023, so the movie show on the maps are those streamed this day. If you want to have those of the current day you need to update the database through the codes in the scrapping section.

# %%
def HourConversion(string):                  
    return datetime.strptime(string, '%H:%M') 

def MovieMapping(data,MinHour:'HHhMM',MaxHour:'HHhMM'):     
    HeureDebut = datetime.strptime(MinHour, "%Hh%M")
    HeureFin = datetime.strptime(MaxHour, "%Hh%M")
    
    
    data['time'] = data['heure'].apply(lambda x: HourConversion(x))
    AdjustedData = data[data['time']>= HeureDebut]
    AdjustedData = AdjustedData[AdjustedData['time'] <= HeureFin]
    
    MovieMap = folium.Map(location=[48.8566, 2.3522], zoom_start=12)
    GeoVisited = {}

    for index, row in AdjustedData.iterrows():
        lat = row['geo'].split(',')[0]
        lon = row['geo'].split(',')[1]
    
        content = "<h4 style='color:black;'>" + row['nom'] + "</h4>" \
                "<p style='font-size:16px;'>" + row['etablissement'] + "</p>"\
                "<p style='font-size:16px;'>" + row['heure'] + "</p>"
        
        if (lat,lon) not in GeoVisited.keys():
            GeoVisited[(lat,lon)] = MarkerCluster().add_to(MovieMap)
            folium.Marker(location=(lat,lon), popup = content, max_width=500).add_to(GeoVisited[(lat,lon)])
        else:
            folium.Marker(location=(lat,lon), popup = content, max_width=500).add_to(GeoVisited[(lat,lon)])
    MovieMap.save("Outputs/Maps/MovieMap.html")

# %% [markdown]
# #### *Example*
# We will use the previous function to create a map showing all the movies streamed in Paris on 28th December 2023 whose cinema sessions begins between 5:30 PM (17h30) and 10:00 PM (22h00).
#
# To see the final Map, open the file name MovieMap.html in Outputs/Maps though your webbrowser

# %%
program = pd.read_csv('Outputs/DataSets/DataCinema.csv')
MovieMapping(program,'17h30','22h00')

# %% [markdown]
# ### Theater
#
# The following function creates the map of the theater play played on a given day. You can choose the day as an argument of the function. Pay attention that the database had been lastly updated on 28th December of 2023. If you use the function a longtime after this date, don't hesitate to run webscrapping codes again.

# %%
def TheaterMap(data:'Pandas DataFrame',date:'YYYY-MM-DD'):

    user_date = datetime.strptime(date, '%Y-%m-%d')
    data['date début'] = pd.to_datetime(data['date début'])
    data['date fin'] = pd.to_datetime(data['date fin'])
    filtered_data = data[(data['date début'] <= user_date) & (user_date <= data['date fin'])]

    paris_coordinates = [48.8566, 2.3522]
    my_map = folium.Map(location=paris_coordinates, zoom_start=12)

    for index, row in filtered_data.iterrows():
        establishment_name = row['etablissement']
        address = row['adresse']
        show_name = row['nom']
        average_price = row['prix moyen']

        coordinates = [float(coord.strip('()')) for coord in row['Coordonnees'].split(',')]
        popup_text = f"<b>{establishment_name}</b><br>Adresse: {address}<br>Pièce: {show_name}<br>Prix moyen: {average_price} €"
        folium.Marker(location=coordinates, popup=popup_text).add_to(my_map)
    
    my_map.save("Outputs/Maps/Theatermap.html")

# %% [markdown]
# #### *Example*
# We create a Map with all the theaters plays play on 12th January of 2024. If you want to create a map for an other date pay attention to the format of the date that has to be 'YYYY-MM-DD'.
# To see the map, open TheaterMap.html in the Outputs/Maps section.

# %%
DataTheater = pd.read_csv('Outputs/DataSets/DataTheatre_base_finale.csv', sep=';')
TheaterMap(DataTheater,'2024-01-12' )

# %% [markdown]
# ### Concerts
#
# Here are provided the functions used to make a map of concerts play on a given day in Paris.

# %%
def ClassicalMap(data:'Pandas DataFrame',date:'YYYY-MM-DD'):
    user_date = datetime.strptime(date, '%Y-%m-%d')
    data['date datetime'] = pd.to_datetime(data['date datetime'])
    
    data['date datetime'] = data['date datetime'].apply(lambda x: x.replace(hour=0, minute=0, second=0, microsecond=0))
    user_date = user_date.replace(hour=0, minute=0, second=0, microsecond=0)    
    filtered_data = data[(data['date datetime'] == user_date)]
    paris_coordinates = [48.8566, 2.3522]
    my_map = folium.Map(location=paris_coordinates, zoom_start=12)

    for index, row in filtered_data.iterrows():
        establishment_name = row['etablissement']
        address = row['adresse']
        show_name = row['nom']
        average_price = row['prix moyen']
        time = row['heure']
        
        coordinates = [float(coord.strip('()')) for coord in row['coordonnees'].split(',')]

        popup_text = f"<b>{establishment_name}</b><br>Adresse: {address}<br>Concert: {show_name}<br>Heure: {time}<br>Prix moyen: {average_price} €"
        folium.Marker(location=coordinates, popup=popup_text).add_to(my_map)
    
    my_map.save("Outputs/Maps/Classicmap.html")

# %% [markdown]
# #### *Example*
#
# We plot a map with all the concert played on 29th december of 2023 in Paris

# %%
DataClassical = pd.read_csv('Outputs/DataSets/DataMusiqueClassique_v8.csv', sep=',')
ClassicalMap(DataClassical,'2023-12-29')

# %% [markdown]
# ## **II. Statistics**
#
# In this section we review the main statistics we realised with the databases we produced in the first section.
# We will go through various topics such as finding the most relevant place for you to hang out in Paris, according to your tastes.

# %% [markdown]
# ### Cinema
# This section will contain statistics made from the databases we created or found. For the cinemas I will use the Open database from the City of Paris about cinemas of the town. The database issued by webscrapping only contains data about one day so it's hard to make statistics from it.
#
# The original file is located in Resources/Data and is named ListeCinema.csv.
# We first read the file trough pandas and import the necessary modules :

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
DataCinemaParis = pd.read_csv('Ressources/Data/ListeCinema.csv', sep = ';')
DataCinemaParis = DataCinemaParis[DataCinemaParis['dep'] == 75]
DataCinemaParis.head()
# Out:
#    ndeg_auto  dep                              nom region_administrative  \
# 0       12.0   75                     UGC GEORGE V         ILE-DE-FRANCE
# 1       31.0   75                    UGC NORMANDIE         ILE-DE-FRANCE
# 2       35.0   75                           BALZAC         ILE-DE-FRANCE
# 3       54.0   75  GAUMONT CHAMPS ELYSEES MARIGNAN         ILE-DE-FRANCE
# 4       55.0   75                  ELYSEES LINCOLN         ILE-DE-FRANCE
#
#                            adresse  code_insee                  commune  \
# 0    146 AVENUE DES CHAMPS ELYSEES       75108  Paris 8e Arrondissement
# 1    116 AVENUE DES CHAMPS ELYSEES       75108  Paris 8e Arrondissement
# 2                     1 RUE BALZAC       75108  Paris 8e Arrondissement
# 3  27/33 AVENUE DES CHAMPS ELYSEES       75108  Paris 8e Arrondissement
# 4                   14 RUE LINCOLN       75108  Paris 8e Arrondissement
#
#   situation_geographique  ecrans  fauteuils  ... nombre_de_films_inedits_2020  \
# ...

# %% [markdown]
# #### Wich part of the city has better facilities for Cinema lovers ?
# This section deals with general statistics on cinemas in Paris such as the nulber of cinema, the number of screen or seat per district. This allows us to find the part of the town that has more facilities on Cinema.

# %%
DataCinemaParis.shape
# Out:
# (78, 37)

# %%
print(DataCinemaParis['ecrans'].mean())
print(DataCinemaParis['fauteuils'].mean())
# Out:
# 5.128205128205129
# 906.4102564102565

# %%
MeanSeats = DataCinemaParis.groupby('commune')['fauteuils'].mean()
MeanScreen = DataCinemaParis.groupby('commune')['ecrans'].mean()
print(MeanSeats, MeanScreen)
# Out:
# commune
# Paris 10e Arrondissement     299.666667
# Paris 11e Arrondissement     416.000000
# Paris 12e Arrondissement    2088.333333
# Paris 13e Arrondissement    1116.800000
# Paris 14e Arrondissement     980.333333
# Paris 15e Arrondissement    1542.750000
# Paris 16e Arrondissement     617.000000
# Paris 17e Arrondissement     538.200000
# Paris 18e Arrondissement    1124.500000
# Paris 19e Arrondissement    1947.750000
# Paris 1er Arrondissement    3894.000000
# Paris 20e Arrondissement    1267.000000
# Paris 2e Arrondissement     2706.000000
# Paris 3e Arrondissement      557.000000
# Paris 4e Arrondissement      238.000000
# Paris 5e Arrondissement      209.100000
# Paris 6e Arrondissement      540.133333
# Paris 8e Arrondissement      946.142857
# Paris 9e Arrondissement      617.333333
# Name: fauteuils, dtype: float64 commune
# Paris 10e Arrondissement     2.333333
# Paris 11e Arrondissement     3.000000
# Paris 12e Arrondissement    10.333333
# ...

# %%
plt.bar(MeanSeats.index, MeanSeats)
plt.xticks(rotation = 45, ha='right')
plt.grid()
plt.title('Average number of Seats per District')
plt.show()

# %%
plt.bar(MeanScreen.index, MeanScreen)
plt.xticks(rotation = 45, ha='right')
plt.grid()
plt.title('Average number of Screen per district')
plt.show()

# %% [markdown]
# Those results seem to show us that the first district of Paris is the one with the more facilities if you like big cinemas. However those results are mostly due to the 'UGC Chatelet les halles' that has 27 rooms ! The other cinemas of the Paris 1er Arrondissement are way smaller than this one. The 2nd Arrondissement also has a high number of seats due to 'Le Grand  Rex' and its 14 rooms. If you like huge cinemas with a tremendous number of facilities, those arrondissements are the one you need to get to !

# %% [markdown]
# #### What kind movie people watch in different districts ?

# %%
FrenchMovie = DataCinemaParis.groupby('commune')['pdm_en_entrees_des_films_francais_2020'].mean()
print(FrenchMovie)
# Out:
# commune
# Paris 10e Arrondissement    49.876972
# Paris 11e Arrondissement    54.494130
# Paris 12e Arrondissement    46.212740
# Paris 13e Arrondissement    47.368508
# Paris 14e Arrondissement    52.299938
# Paris 15e Arrondissement    43.335309
# Paris 16e Arrondissement    50.828104
# Paris 17e Arrondissement    46.203511
# Paris 18e Arrondissement    45.415024
# Paris 19e Arrondissement    40.781526
# Paris 1er Arrondissement    38.955951
# Paris 20e Arrondissement    43.005345
# Paris 2e Arrondissement     26.556997
# Paris 3e Arrondissement     55.864979
# Paris 4e Arrondissement     38.120070
# Paris 5e Arrondissement     42.248007
# Paris 6e Arrondissement     47.158843
# Paris 8e Arrondissement     46.993894
# Paris 9e Arrondissement     39.593567
# Name: pdm_en_entrees_des_films_francais_2020, dtype: float64

# %%
plt.bar(FrenchMovie.index, FrenchMovie)
plt.xticks(rotation = 45, ha='right')
plt.title('Average market share of the Frecnh Cinema per district')
# Out:
# Text(0.5, 1.0, 'Average market share of the Frecnh Cinema per district')

# %% [markdown]
# The Arrondissements where French Cinema holds the most marketshare are number 4 and 11. In the 2nd Arrondissement the score of the French Cinema is the lowest among all the capital city having only 26,55 average Marketshare.

# %% [markdown]
# #### Theater

# %%
df = pd.read_csv('Outputs/DataSets/DataTheatre_base_finale.csv', sep=';')

# %% [markdown]
# We are looking for the number of plays per district
#
# This first step helps us understand the cultural activity you will find in each district of Paris

# %%
result_df = df.groupby('commune')['etablissement'].count().reset_index()
result_df = result_df.rename(columns={'etablissement': 'nombre_de_pieces'})
print(result_df)
# Out:
#       commune  nombre_de_pieces
# 0   Paris 10e                52
# 1   Paris 11e                49
# 2   Paris 12e                38
# 3   Paris 13e                14
# 4   Paris 14e                31
# 5   Paris 15e                26
# 6   Paris 16e                13
# 7   Paris 17e                13
# 8   Paris 18e                79
# 9   Paris 19e                37
# 10  Paris 1er                10
# 11  Paris 20e                19
# 12   Paris 2e                18
# 13   Paris 3e                 4
# 14   Paris 4e                46
# 15   Paris 5e                25
# 16   Paris 6e                29
# 17   Paris 7e                 1
# 18   Paris 8e                37
# 19   Paris 9e                44

# %%
result_df['arrondissement'] = result_df['commune'].str.extract('(\d+)', expand=False).astype(int)
df_classe = result_df.sort_values(by='arrondissement')
print(df_classe)
# Out:
#       commune  nombre_de_pieces  arrondissement
# 10  Paris 1er                10               1
# 12   Paris 2e                18               2
# 13   Paris 3e                 4               3
# 14   Paris 4e                46               4
# 15   Paris 5e                25               5
# 16   Paris 6e                29               6
# 17   Paris 7e                 1               7
# 18   Paris 8e                37               8
# 19   Paris 9e                44               9
# 0   Paris 10e                52              10
# 1   Paris 11e                49              11
# 2   Paris 12e                38              12
# 3   Paris 13e                14              13
# 4   Paris 14e                31              14
# 5   Paris 15e                26              15
# 6   Paris 16e                13              16
# 7   Paris 17e                13              17
# 8   Paris 18e                79              18
# 9   Paris 19e                37              19
# ...

# %%
fig, ax = plt.subplots(figsize=(20, max(6, len(result_df) * 0.3)))
ax.bar(result_df['commune'], result_df['nombre_de_pieces'], color='blue')
ax.set_title('Nombre de pièces par quartier')
plt.tight_layout()
plt.show()

# %% [markdown]
# We are looking for the number of plays per theatre.
#
# In this second step, we extract the number of different plays each theater will propose from now on until the end of the season (june)

# %%
df_pieces_par_etablissement = df.groupby('etablissement')['nom'].count().reset_index()
df_pieces_par_etablissement = df_pieces_par_etablissement.rename(columns={'nom': 'nombre_de_pieces'})
print(df_pieces_par_etablissement)
# Out:
#                         etablissement  nombre_de_pieces
# 0                            Alhambra                 2
# 1                      Apollo Théâtre                 1
# 2                    Artistic Théâtre                 1
# 3        Athénée Théâtre Louis-Jouvet                 3
# 4                    Au Port du Salut                 1
# ..                                ...               ...
# 120             Théâtre du Rond-Point                15
# 121  Théâtre du Soleil - Cartoucherie                 3
# 122               Théâtre Édouard VII                 2
# 123                À la Folie Théâtre                 5
# 124             Église Saint-Augustin                 1
#
# [125 rows x 2 columns]

# %% [markdown]
# We are looking for the number of theatres per quarter

# %%
df_liste_theatre = df[['commune', 'etablissement']].drop_duplicates()
nbtheatre_df = df_liste_theatre.groupby('commune')['etablissement'].count().reset_index()

nbtheatre_df = nbtheatre_df.rename(columns={'etablissement': 'nombre_de_theatres'})

# %%
nbtheatre_df['arrondissement'] = nbtheatre_df['commune'].str.extract('(\d+)', expand=False).astype(int)

nbtheatre_dfordonne = nbtheatre_df.sort_values(by='arrondissement')

print(nbtheatre_dfordonne)
# Out:
#       commune  nombre_de_theatres  arrondissement
# 10  Paris 1er                   3               1
# 12   Paris 2e                   5               2
# 13   Paris 3e                   2               3
# 14   Paris 4e                   6               4
# 15   Paris 5e                   5               5
# 16   Paris 6e                   5               6
# 17   Paris 7e                   1               7
# 18   Paris 8e                   9               8
# 19   Paris 9e                  15               9
# 0   Paris 10e                  12              10
# 1   Paris 11e                  14              11
# 2   Paris 12e                   5              12
# 3   Paris 13e                   4              13
# 4   Paris 14e                   8              14
# 5   Paris 15e                   4              15
# 6   Paris 16e                   3              16
# 7   Paris 17e                   3              17
# 8   Paris 18e                  11              18
# ...

# %% [markdown]
# We are looking for the mean price per quarter

# %%
df['prix moyen'] = df['prix moyen'].astype(str)
df['prix moyen'] = pd.to_numeric(df['prix moyen'].str.extract('(\d+)')[0], errors='coerce')
df['prix moyen'] = df['prix moyen'].round(1)
df_prix_moyen = df.groupby('commune')['prix moyen'].mean().reset_index()
print(df_prix_moyen)
# Out:
#       commune  prix moyen
# 0   Paris 10e   30.920000
# 1   Paris 11e   23.717391
# 2   Paris 12e   17.631579
# 3   Paris 13e   29.000000
# 4   Paris 14e   25.964286
# 5   Paris 15e   22.333333
# 6   Paris 16e   27.250000
# 7   Paris 17e   27.400000
# 8   Paris 18e   21.913043
# 9   Paris 19e   16.107143
# 10  Paris 1er   55.000000
# 11  Paris 20e   19.388889
# 12   Paris 2e   31.647059
# 13   Paris 3e   32.000000
# 14   Paris 4e   24.547619
# 15   Paris 5e   24.708333
# 16   Paris 6e   26.826087
# 17   Paris 7e   27.000000
# 18   Paris 8e   34.121212
# 19   Paris 9e   30.470588

# %%
df_prix_moyen['arrondissement'] = df_prix_moyen['commune'].str.extract('(\d+)', expand=False).astype(int)
df_ordonne = df_prix_moyen.sort_values(by='arrondissement')
print(df_ordonne)
# Out:
#       commune  prix moyen  arrondissement
# 10  Paris 1er   55.000000               1
# 12   Paris 2e   31.647059               2
# 13   Paris 3e   32.000000               3
# 14   Paris 4e   24.547619               4
# 15   Paris 5e   24.708333               5
# 16   Paris 6e   26.826087               6
# 17   Paris 7e   27.000000               7
# 18   Paris 8e   34.121212               8
# 19   Paris 9e   30.470588               9
# 0   Paris 10e   30.920000              10
# 1   Paris 11e   23.717391              11
# 2   Paris 12e   17.631579              12
# 3   Paris 13e   29.000000              13
# 4   Paris 14e   25.964286              14
# 5   Paris 15e   22.333333              15
# 6   Paris 16e   27.250000              16
# 7   Paris 17e   27.400000              17
# 8   Paris 18e   21.913043              18
# 9   Paris 19e   16.107143              19
# 11  Paris 20e   19.388889              20

# %% [markdown]
# # II- Regressions
#
# In this section, we explore links between quarters, number of theatres and the price of the tickets

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# We will have a closer look at Paris's district to test if their level of wealth has a significant impact on the price of theatre's tickets
#
# At first sight, it seems logicial that the more wealthy a quarter is, the higher prices will be. But how to measure it effectively ? In fact, it is difficult to measure quarter's wealth. We decided to use a simple indicator: the price of a square meter in every quarter assuming that the higher it is, the higher the purchasing power of its inhabitant will be.
#
# First step: we scraped a website with the 2023-data and saved them in the 'Prixm2' csv file

# %%
# !pip install lxml
import bs4
import lxml
import pandas as pd
import urllib
from bs4 import BeautifulSoup
from urllib import request
import numpy as np

# %%
url = 'https://www.journaldunet.com/patrimoine/prix-immobilier/paris/ville-75056'
request_text = request.urlopen(url).read()
page = bs4.BeautifulSoup(request_text, 'html.parser')

# %%
rows = page.find_all('tr')
informations = []

for row in rows:
    link = row.find('a')
    columns = row.find_all('td')
    if link and len(columns) > 1:
        arrondissement = link.text.strip()
        prix = columns[1].text.strip()
        informations.append({'arrondissement': arrondissement, 'prix': prix})

df2 = pd.DataFrame(informations)

df2['prix'] = df2['prix'].str.replace('\D', '', regex=True).astype(int) #removes all the non-numerical (but keeps the 2 of the m2) 
df2['prix'] = df2['prix'].astype(str).str[:-1].astype(int) #removes the last figure of our number (here the 2 from 'm2')

df2.to_csv('Prixm2.csv', index = False)

# %% [markdown]
# #### Regression of the price of the ticket on the price of the square meter

# %%
X=df2['prix']
y = df_ordonne['prix moyen']
X = X.values.reshape(-1, 1)
model1 = LinearRegression()
model1.fit(X,y)
y_pred = model1.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red', linewidth=1.5)
plt.xlabel('Prix du m2 dans l arrondissement')
plt.ylabel('Prix du billet')
plt.show()

# %%
print("Pente :", model1.coef_)
print("Fixe :", model1.intercept_)
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Pente : [0.00204138]
# Fixe : 3.6009975662955007
# Mean Squared Error : 48.61064055382661
# R-squared : 0.2190643076094262

# %% [markdown]
# Some conclusions:
#
# 1- our initial intuition seems to be right: the higher the square meter costs, the higher the ticket price is.
#
# 2- Except for one point, results are well shared
#
# 3- Some biais: our sample of prices is made of approximation or mean + we didn't take into account all the plays for which we didn't have the price + we assume that we are lacking of data for some theatre we decided not to include in this set (theatre for which the website we scrapped had no information). The R-squared shows that this model is unlikely to predict a good relation between the price of the ticket and the wealth of the quarter. Nonetheless it remains useful to see the general idea of this positive correlation

# %% [markdown]
# We have a closer look at the link between the number of plays in a quarter and the price of the ticket

# %%
A = df_classe['nombre_de_pieces']
b = df_ordonne['prix moyen']
A= A.values.reshape(-1, 1)
model2 = LinearRegression()
model2.fit(A,b)
b_pred = model2.predict(A)
plt.scatter(A, b)
plt.plot(A, b_pred, color='yellow', linewidth=1.5)
plt.xlabel('Nombre de pieces dans le quartier')
plt.ylabel('Prix du billet')
plt.show()

# %%
print("Pente :", model2.coef_)
print("Fixe :", model2.intercept_)
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Pente : [-0.14292042]
# Fixe : 31.57775047798494
# Mean Squared Error : 48.61064055382661
# R-squared : 0.2190643076094262

# %% [markdown]
# Some conclusions:
# Here we have an interesant result: the higher plays you have in the same quarter, the lower the price of the ticket will be, which means that there is some kind of competition you could take advantage of when choosing your play and the range of price you are willing to pay.

# %% [markdown]
# We have a closer look at the link between the number of estblishments in a quarter and the price of the ticket

# %%
C = nbtheatre_dfordonne['nombre_de_theatres']
d = df_ordonne['prix moyen']
C= C.values.reshape(-1, 1)

# %%
model3 = LinearRegression()
model3.fit(C,d)
d_pred= model3.predict(C)

# %%
plt.scatter(C, d)
plt.plot(C, d_pred, color='green', linewidth=1.5)
plt.xlabel('Nombre de théâtre dans le quartier')
plt.ylabel('Prix du billet')
plt.show()

# %%
print("Pente :", model3.coef_)
print("Fixe :", model3.intercept_)
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Pente : [-0.19168946]
# Fixe : 28.59538725581703
# Mean Squared Error : 48.61064055382661
# R-squared : 0.2190643076094262

# %% [markdown]
# Conlusions:
#
# 1- the price of the ticket is slightly liked to the number of theatres in the quarter
#
# 2- Nonetheless, it is supposed to go down if the number of theater goes up, which means that there is some kind of competit

# %% [markdown]
# # III- General conclusion for theatres
#
# It finally appears that the two factors are to be taken into account when choosing your play: the quarter wherethe theatre is & the number of plays that are avaible in the same quarter on the date you chose. For the firt one, you can check in the csv file 'Prixm2' to check wether the quarter is reach or not (in this case, the price is positively linked to the general wealth).

# %% [markdown]
# ### Statistics on classical music concerts in Paris

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/onyxia/work/Maps_cultural_life_Paris/Outputs/DataSets/DataMusiqueClassique_v8.csv')

# %%
df.head(1)
# Out:
#                                             nom  \
# 0  Orchestre Classik Ensemble et David Braccini
#
#                          etablissement                         Date  \
# 0  Sainte-Chapelle - Palais de la Cité  Mercredi 27 Décembre  18h00
#
#                                 adresse    commune     prix  \
# 0  8 boulevard du Palais, Paris, France  Paris 1er  unknown
#
#              coordonnees  prix min  prix max prix unique prix moyen  \
# 0  (48.854843, 2.345141)       NaN       NaN     unknown    unknown
#
#          date datetime  heure
# 0  2023-12-27 18:00:00  18h00

# %% [markdown]
# #### How many classical music concerts are currently scheduled?

# %%
print("{} classical music concerts are currently scheduled in Paris between December and May".format(len(df)))
# Out:
# 674 classical music concerts are currently scheduled in Paris between December and May

# %% [markdown]
# #### Where to find classical music concerts in Paris

# %%
arrondissements_df = df.groupby('commune')['nom'].count().reset_index()

arrondissements_df = arrondissements_df.rename(columns={'nom': 'nombre_de_concerts'})

arrondissements_df = arrondissements_df.sort_values(by = 'nombre_de_concerts', ascending = False)

arrondissements_df.head(5)
# Out:
#       commune  nombre_de_concerts
# 29   Paris 8e                 120
# 20  Paris 19e                 115
# 26   Paris 5e                 115
# 17  Paris 16e                  47
# 27   Paris 6e                  44

# %%
chart_1 = arrondissements_df.head(20).plot(x = 'commune', y = 'nombre_de_concerts',kind = 'bar')

for i, value in enumerate(arrondissements_df.head(20)['nombre_de_concerts']):
    chart_1.text(i, value + 1, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# #### As can be seen from the chart above, the majority of classical music concerts take place in the 8th and 19th arrondissements, and the 5th arrondissement, which comes first in the summer, followed by the 16th arrondissement, which seems logical and corresponds overall to the distribution of the major concert halls in Paris, except for the 5th arrondissement, where the majority of concerts take place in churches.

# %% [markdown]
# ### Which concert halls offer the most concerts?

# %%
salles_df = df.groupby('etablissement')['nom'].count().reset_index()
salles_df = salles_df.rename(columns={'nom': 'nombre_de_concerts'})
salles_df = salles_df.sort_values(by = 'nombre_de_concerts', ascending = False)
salles_df.head(5)
# Out:
#                                         etablissement  nombre_de_concerts
# 85                                Église Saint-Éphrem                  95
# 30  Grande salle Pierre Boulez - Philharmonie de P...                  77
# 62                         Théâtre des Champs-Élysées                  62
# 41                Maison de la Radio et de la Musique                  45
# 90                             Église de la Madeleine                  39

# %%
print("there are {} concert halls currently offering classical music concerts in Paris".format(len(salles_df)))
# Out:
# there are 98 concert halls currently offering classical music concerts in Paris

# %%
nombre_eglises = salles_df['etablissement'].str.lower().str.count('église'.lower())
total_eglises = nombre_eglises.sum()

print(f"number of churches hosting classical concerts : {total_eglises}")
# Out:
# number of churches hosting classical concerts : 34

# %%
nombre_philharmonie = salles_df['etablissement'].str.lower().str.count('Philharmonie'.lower())
total_philharmonie_salles = nombre_philharmonie.sum()

print(f"Number of rooms in the Philharmonie : {total_philharmonie_salles}")
# Out:
# Number of rooms in the Philharmonie : 5

# %%
top20_salles_df = salles_df.head(20)

top20_salles_df.plot(x = 'etablissement',y = 'nombre_de_concerts',kind = 'bar')
# Out:
# <Axes: xlabel='etablissement'>

# %%
salles_philharmonie = salles_df[salles_df['etablissement'].str.contains('philharmonie', case=False, na=False)]
total_philharmonie_concerts = salles_philharmonie['nombre_de_concerts'].sum()

total_philharmonie = pd.DataFrame({'etablissement': ['Total Philharmonie'], 'nombre_de_concerts': [total_philharmonie_concerts]})

salles_v2_df = pd.concat([total_philharmonie, salles_df], ignore_index=True)
salles_v2_df.head()
# Out:
#                                        etablissement  nombre_de_concerts
# 0                                 Total Philharmonie                 115
# 1                                Église Saint-Éphrem                  95
# 2  Grande salle Pierre Boulez - Philharmonie de P...                  77
# 3                         Théâtre des Champs-Élysées                  62
# 4                Maison de la Radio et de la Musique                  45

# %%
top20_salles_v2_df = salles_v2_df.head(20)


ax = top20_salles_v2_df.plot(x='etablissement', y='nombre_de_concerts', kind='bar', legend=False)
ax.patches[0].set_facecolor('red')

for i, value in enumerate(top20_salles_v2_df['nombre_de_concerts']):
    ax.text(i, value + 1, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# #### When all the Philharmonie's halls are grouped together, it once again becomes the city's most important venue for classical music concerts.

# %% [markdown]
# ### How many concerts are there each month?

# %%
df['date datetime'] = pd.to_datetime(df['date datetime'])
concerts_par_mois = df.groupby(df['date datetime'].dt.to_period('M')).size().reset_index(name='nombre de concerts')

concerts_par_mois
# Out:
#   date datetime  nombre de concerts
# 0       2023-12                  52
# 1       2024-01                 225
# 2       2024-02                 114
# 3       2024-03                 149
# 4       2024-04                  66
# 5       2024-05                  68

# %%
concerts_par_mois['date numeric'] = concerts_par_mois['date datetime'].dt.to_timestamp().astype(int)


plt.figure(figsize=(8, 8))
plt.plot(concerts_par_mois['date numeric'], concerts_par_mois['nombre de concerts'], marker='o', linestyle='-', color='b')


plt.title('Nombre de Concerts par Mois à date', fontsize=16)
plt.xlabel('Mois', fontsize=14)
plt.ylabel('Nombre de Concerts', fontsize=14)


plt.xticks(concerts_par_mois['date numeric'], [period.strftime('%b %Y') for period in concerts_par_mois['date datetime']], rotation=45, fontsize=14)
plt.yticks(fontsize=14)


for i, value in enumerate(concerts_par_mois['nombre de concerts']):
    plt.text(
        concerts_par_mois['date numeric'][i], 
        value + 2, 
        str(value), 
        ha='center', 
        fontsize=14,
        bbox=dict(facecolor='white', alpha=0.7, edgecolor='white')
    )


plt.show()

# %% [markdown]
# #### However, this chart is not very representative, as some concerts may not yet be scheduled. We would need the historical schedule, which is not available on the site we scrapped. It would be interesting to compare this chart with the same one from a January or February 2024 scrap.

# %% [markdown]
# ### Prices by area and regression of the price on the population categories

# %%
df['prix moyen'] = pd.to_numeric(df['prix moyen'], errors='coerce')

result = df.groupby('commune')['prix moyen'].agg(['mean', 'count']).reset_index().dropna()
result.columns = ['commune', 'prix moyen', 'nombre de datapoints']

result.sort_values(by='prix moyen', ascending=False, inplace=True)

result
# Out:
#                  commune  prix moyen  nombre de datapoints
# 33            Versailles  103.466667                    15
# 3   Boulogne-Billancourt   45.500000                     2
# 23              Paris 2e   38.000000                     1
# 29              Paris 8e   37.177215                    79
# 25              Paris 4e   33.000000                     4
# 27              Paris 6e   30.750000                    28
# 30              Paris 9e   29.411765                    17
# 21             Paris 1er   27.500000                     2
# 6             Guyancourt   25.000000                     1
# 24              Paris 3e   24.000000                     2
# 0            Alfortville   21.500000                     1
# 26              Paris 5e   21.429907                   107
# 2                Bagneux   19.000000                     1
# 12             Paris 11e   19.000000                     4
# 13             Paris 12e   18.500000                     1
# ...

# %% [markdown]
# #### The database we scrapped lacks information on prices, especially for larger venues (incl. Philharmonie), which makes this ranking less accurate than it could have been.

# %% [markdown]
# #### We observe that Versailles is very expensive, this is due to the fact that the concerts in Versailles take place in the chapelle royale which is a small very premiul hall.

# %% [markdown]
# #### But the relative absence of datapoints for large concert halls is interesting because it allows us to evaluate the cultural activity of neighborhoods independently of the bias caused by the presence of these large halls (such as the Philharmonie). We'll try to see if there's a link between ticket price and the proportion of the neighborhood's population who are CSP+ and then retired (which are the populations usually found in concert halls).

# %% [markdown]
# #### We will scrape the percentages of CSP+ and retired people on the INSEE website to regress the average price of concerts on the percentage of CSP+ and retired people.

# %%
# !pip install -q lxml

import bs4
import lxml
import pandas as pd
import urllib
from bs4 import BeautifulSoup
from urllib import request

# %% [markdown]
# PLEASE : note that this code takes some time to run (around one minute)...please wait until the result displays before moving on

# %%
base_url = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-751'
liste_arr = [f"{i:02}" for i in range(1, 21)]


urls = [base_url + arr for arr in liste_arr]

Versailles = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-78646' 
Boulogne = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-92012' 
Guyancourt = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-78297'  
Alfortville = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-94002' 
Bagneux = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-92007' 
Corbeil = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-91174' 

urls.append(Versailles)
urls.append(Boulogne)
urls.append(Guyancourt)
urls.append(Alfortville)
urls.append(Bagneux)
urls.append(Corbeil)



CSP = {}
i = 1
special_cities = ["Versailles", "Boulogne-Billancourt", "Guyancourt", "Alfortville", "Bagneux", "Corbeil-Essonnes"]


for url in urls:
    request_text = request.urlopen(url).read()
    page = bs4.BeautifulSoup(request_text, 'html.parser')
    
    table = page.find("table", {"id": "produit-tableau-POP_T5", "class": "tableau-produit"})
    th_element = table.find("th", string="Cadres et professions intellectuelles supérieures")
    tr_element = th_element.find_parent("tr")
    td_elements = tr_element.find_all("td")
    chiffre = td_elements[-1].text.strip()
    chiffre_clean = float(chiffre.replace(',', '.'))

    if i == 1 :
        CSP[f"Paris {i}er"] = chiffre_clean
        i += 1
    elif 1 < i <= 20: 
        CSP[f"Paris {i}e"] = chiffre_clean
        i += 1
    else : 
        CSP[special_cities[i-21]] = chiffre_clean
        i +=1
        

CSP
# Out:
# {'Paris 1er': 33.8,
#  'Paris 2e': 40.5,
#  'Paris 3e': 36.7,
#  'Paris 4e': 32.5,
#  'Paris 5e': 31.9,
#  'Paris 6e': 30.2,
#  'Paris 7e': 31.0,
#  'Paris 8e': 33.3,
#  'Paris 9e': 40.4,
#  'Paris 10e': 35.0,
#  'Paris 11e': 34.6,
#  'Paris 12e': 30.6,
#  'Paris 13e': 26.0,
#  'Paris 14e': 31.1,
#  'Paris 15e': 32.1,
#  'Paris 16e': 28.5,
#  'Paris 17e': 33.6,
#  'Paris 18e': 28.4,
#  'Paris 19e': 22.6,
#  'Paris 20e': 24.2,
#  'Versailles': 27.8,
#  'Boulogne-Billancourt': 33.0,
#  'Guyancourt': 21.7,
#  'Alfortville': 15.8,
#  'Bagneux': 13.2,
#  'Corbeil-Essonnes': 6.2}

# %%
result['% CSP'] = result['commune'].map(CSP)
result
# Out:
#                  commune  prix moyen  nombre de datapoints  % CSP
# 33            Versailles  103.466667                    15   27.8
# 3   Boulogne-Billancourt   45.500000                     2   33.0
# 23              Paris 2e   38.000000                     1   40.5
# 29              Paris 8e   37.177215                    79   33.3
# 25              Paris 4e   33.000000                     4   32.5
# 27              Paris 6e   30.750000                    28   30.2
# 30              Paris 9e   29.411765                    17   40.4
# 21             Paris 1er   27.500000                     2   33.8
# 6             Guyancourt   25.000000                     1   21.7
# 24              Paris 3e   24.000000                     2   36.7
# 0            Alfortville   21.500000                     1   15.8
# 26              Paris 5e   21.429907                   107   31.9
# 2                Bagneux   19.000000                     1   13.2
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np


result_clean = result.dropna(subset=['% CSP', 'prix moyen'])


X = result_clean['% CSP'].values.reshape(-1, 1)
y = result_clean['prix moyen'].values


model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)


plt.scatter(X, y, label='Data points')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Model')
plt.xlabel('% CSP')
plt.ylabel('prix moyen')
plt.legend()
plt.show()


print(f'Coefficients : {model.coef_}')
print(f'Intercept : {model.intercept_}')
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Coefficients : [0.42281478]
# Intercept : 19.550660020627195
# Mean Squared Error : 391.82229367005993
# R-squared : 0.0392672198556111

# %%
result_clean = result[result['commune'] != 'Versailles'].dropna(subset=['% CSP', 'prix moyen'])


X = result_clean['% CSP'].values.reshape(-1, 1)
y = result_clean['prix moyen'].values


model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)


plt.scatter(X, y, label='Data points')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Model')
plt.xlabel('% CSP')
plt.ylabel('prix moyen')
plt.legend()
plt.show()

print(f'Coefficients : {model.coef_}')
print(f'Intercept : {model.intercept_}')
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Coefficients : [0.48126837]
# Intercept : 13.047060517070038
# Mean Squared Error : 47.31934043710551
# R-squared : 0.3184775358022214

# %% [markdown]
# #### In the first version, the regression is highly biased by the royal chappellle of Versailles, so in a second step we remove this datapoint to obtain a model with an R2 of around 31.85% of the variance in the dependent variable is explained by the model, indicating a moderate fit. The regression indicates that the average price of a concert increases by around 0.48 for each one-percent increase in the CSP + population.

# %% [markdown]
# #### Now we add the retired people

# %%
base_url = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-751'
liste_arr = [f"{i:02}" for i in range(1, 21)]


urls = [base_url + arr for arr in liste_arr]

Versailles = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-78646' 
Boulogne = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-92012' 
Guyancourt = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-78297'  
Alfortville = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-94002' 
Bagneux = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-92007' 
Corbeil = 'https://www.insee.fr/fr/statistiques/2011101?geo=COM-91174' 

urls.append(Versailles)
urls.append(Boulogne)
urls.append(Guyancourt)
urls.append(Alfortville)
urls.append(Bagneux)
urls.append(Corbeil)



CSP2 = {}

i = 1
special_cities = ["Versailles", "Boulogne-Billancourt", "Guyancourt", "Alfortville", "Bagneux", "Corbeil-Essonnes"]


for url in urls:
    request_text = request.urlopen(url).read()
    page = bs4.BeautifulSoup(request_text, 'html.parser')
    
    table = page.find("table", {"id": "produit-tableau-POP_T5", "class": "tableau-produit"})
    
    th_element1 = table.find("th", string="Cadres et professions intellectuelles supérieures")
    tr_element1 = th_element1.find_parent("tr")
    td_elements1 = tr_element1.find_all("td")
    chiffre1 = td_elements1[-1].text.strip()
    chiffre_clean1 = float(chiffre1.replace(',', '.'))

    th_element2 = table.find("th", string="Retraités")
    tr_element2 = th_element2.find_parent("tr")
    td_elements2 = tr_element2.find_all("td")
    chiffre2 = td_elements2[-1].text.strip()
    chiffre_clean2 = float(chiffre2.replace(',', '.'))

    chiffre_clean = chiffre_clean1 + chiffre_clean2

    if i == 1 :
        CSP2[f"Paris {i}er"] = chiffre_clean
        i += 1
    elif 1 < i <= 20: 
        CSP2[f"Paris {i}e"] = chiffre_clean
        i += 1
    else : 
        CSP2[special_cities[i-21]] = chiffre_clean
        i +=1
        

CSP2
# Out:
# {'Paris 1er': 51.4,
#  'Paris 2e': 52.1,
#  'Paris 3e': 52.1,
#  'Paris 4e': 50.2,
#  'Paris 5e': 51.8,
#  'Paris 6e': 52.4,
#  'Paris 7e': 53.2,
#  'Paris 8e': 50.3,
#  'Paris 9e': 54.2,
#  'Paris 10e': 49.1,
#  'Paris 11e': 51.2,
#  'Paris 12e': 50.5,
#  'Paris 13e': 46.3,
#  'Paris 14e': 51.1,
#  'Paris 15e': 52.0,
#  'Paris 16e': 50.2,
#  'Paris 17e': 50.3,
#  'Paris 18e': 43.8,
#  'Paris 19e': 40.400000000000006,
#  'Paris 20e': 42.9,
#  'Versailles': 49.1,
#  'Boulogne-Billancourt': 52.0,
#  'Guyancourt': 36.1,
#  'Alfortville': 34.0,
#  'Bagneux': 30.3,
#  'Corbeil-Essonnes': 22.3}

# %%
result['% CSP et retraités'] = result['commune'].map(CSP2)



result_clean = result.dropna(subset=['% CSP et retraités', 'prix moyen'])


X = result_clean['% CSP et retraités'].values.reshape(-1, 1)
y = result_clean['prix moyen'].values


model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)


plt.scatter(X, y, label='Data points')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Model')
plt.xlabel('% CSP et retraités')
plt.ylabel('prix moyen')
plt.legend()
plt.show()


print(f'Coefficients : {model.coef_}')
print(f'Intercept : {model.intercept_}')
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Coefficients : [0.61593502]
# Intercept : 3.277727382127825
# Mean Squared Error : 374.08099197796764
# R-squared : 0.08276819050833484

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt


result_clean = result[result['commune'] != 'Versailles'].dropna(subset=['% CSP et retraités', 'prix moyen'])


X = result_clean['% CSP et retraités'].values.reshape(-1, 1)
y = result_clean['prix moyen'].values


model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)


plt.scatter(X, y, label='Data points')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Model')
plt.xlabel('% CSP et retraités')
plt.ylabel('prix moyen')
plt.legend()
plt.show()


print(f'Coefficients : {model.coef_}')
print(f'Intercept : {model.intercept_}')
print(f'Mean Squared Error : {mean_squared_error(y, y_pred)}')
print(f'R-squared : {r2_score(y, y_pred)}')
# Out:
# Coefficients : [0.46565865]
# Intercept : 5.536354791441138
# Mean Squared Error : 48.9771104519808
# R-squared : 0.2946013047479725

# %% [markdown]
# ### We note that the R2 is lower than in the first version, so the addition of retirees does not significantly increase the quality of the model.

# %%
result
# Out:
#                  commune  prix moyen  nombre de datapoints  % CSP  \
# 33            Versailles  103.466667                    15   27.8
# 3   Boulogne-Billancourt   45.500000                     2   33.0
# 23              Paris 2e   38.000000                     1   40.5
# 29              Paris 8e   37.177215                    79   33.3
# 25              Paris 4e   33.000000                     4   32.5
# 27              Paris 6e   30.750000                    28   30.2
# 30              Paris 9e   29.411765                    17   40.4
# 21             Paris 1er   27.500000                     2   33.8
# 6             Guyancourt   25.000000                     1   21.7
# 24              Paris 3e   24.000000                     2   36.7
# 0            Alfortville   21.500000                     1   15.8
# 26              Paris 5e   21.429907                   107   31.9
# 2                Bagneux   19.000000                     1   13.2
# ...

# %% [markdown]
# ## **III. Scrapping**
#
# We collected most of our Data using webscrapping. We used BeautifulSoup4 to webscrap the most relevant sites for our project. You can run the functions but the may not work due to modification on the websites.
#
# ### Cinema
# The site we scraped to get the programmation is the flollowing one : https://www.cinefil.com/seances-cinema/paris
# It contains the program of many parisian Cinemas. We first implemented a function name UnitScrapCinema that takes the data of one page. You can find it in Cinema/UnitScrap.py. An example is provided by scrapping the programmation of today for the cinema named UGC Chatelet.
#
# After that the function ScrapCinema defnied in Cinema/ScrapCinema.py takes all the links of the websites and uses the previous function on each page. So is built the database. In order to add the adress and the geographic coordinates, we join our database with and open database found on the Site of the City of Paris. You can find it Ressources/Data/listecinema.csv. We joined on the name of the Cinema, we lost some information (approximately 500 movie) due the difference of spelling that might occur between the databases. Nevertheless as the goal is to realise a map of the movie played on the current day and it leads us to a databae of approximately 1500 movies, we still do so considering that the number of movie print is still a good beginning.

# %% [markdown]
# ### Theatres
#
# #### 1. Website scrapping
# - The site we scraped to get the programmation is the flollowing one : https://www.offi.fr/theatre/pieces-de-theatre.html?criterion_sch_ville=75
# - On this website we found almost all the plays that will take place in Paris from now on until the end of the season (juny). it provided us precises information such as the name of the play, the adress of the theatre, the range of prices of the tickets. You can find the precise code in the folder: TheatresOperas/Scrap Officiel des theatres.
# - Please note that we also scrapped the wikipedia page: 'liste des théâtres et opéras de paris' but we didn't use it in our further analysis
#
# #### 2. Database cleaning
# - The database we extracted from our scrap was uncleaned and we had to make a wide work on it to finally generate a database usefull for statistics (named DataTheatre.csv)
# - First we changed the date format from 'du 26 janvier 2024 au 14 mars 2024' into a 'YYYY-MM-DD' format so that we can convert it into a numerical date and use it to compare to the date you will be choosing and select only the plays avaible.
# - Then we changed the price from a range of price/unique price/unknow price into a medium price so that you will have a general idea on the price it will cost you to attend the play
# - Finally we changed the adress into coordinates to display them on a map
# - You will find the 3 parts of the code in the folder TheatresOperas/Cleanin DataTheatre and the final database DataTheatre_base_finale (you can also find it in Outputs/Datasets)

# %% [markdown]
# ### Concert halls
#
# - We scrapped the l'officiel des spectacles website to generate a database of all classical music concerts from December 2023 onwards. All the related files are stored within the folder Salles_de_concert_Paris
#
#
# #### 1. Website scrapping
#
# - In the section ***1. scrap du site*** the file ***OfficielSpectaclesConcertsScrap.py*** generates a the database by scrapping pages of this link https://www.offi.fr/concerts/programme.html?criterion_sch_ville=75&criterion_SRubrique=classique
# - The module ***ScrapMusiqueClassic.py*** contains the function that is used to scrap each page of the website
#
#
# #### 2. Database cleaning
#
# - In the section ***2. nettoyage de la database*** We make several changes to the database in the script ***ModificationsDatabase.py*** using the module ***Fonctions.py*** to enable us to manipulate the data more easily and create a map displaying all the concerts for a specific day.
# - We first add the geo-coordinatees of the concert halls that we retrieve from the https://api-adresse.data.gouv.fr/search/
# - We make minor changes to the price column to obtain an average tariff on each concert (unfoiortunately there is a lot of missing data)
# - We convert the date of the concerts to the datetime format
#
#
# #### 3. Mapping
#
# - In the ***2. mapping*** section of the ***mappingclassic.py*** file, we define a function that creates an html map displaying the location and time of concerts available on the day entered by the user
# - an example of such a map is available in the file ***Classicmap_example_14.01.2023.html***
